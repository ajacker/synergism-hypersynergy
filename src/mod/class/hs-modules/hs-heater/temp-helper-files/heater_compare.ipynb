# %% [markdown]
# # Heater export vs spreadsheet comparison
#
# This notebook will validate whether the native heater export fields match values from the `True Ambrosia Heater` spreadsheet input data.

# %%
import subprocess
import json
import os
from pathlib import Path

root = Path(r"c:/Users/tangu/Documents/Antigravity/HyperSynergism/synergism-hypersynergy")
print('Workspace root:', root)
print('Node executable available?')
try:
    node_ver = subprocess.run(['node', '-v'], capture_output=True, text=True, check=True)
    print(node_ver.stdout.strip())
except Exception as e:
    print('Node not available:', e)
# Out:
# Workspace root: c:\Users\tangu\Documents\Antigravity\HyperSynergism\synergism-hypersynergy
# Node executable available?
# v24.12.0

# %%
from pathlib import Path
import subprocess

script = Path(r"c:/Users/tangu/Documents/Antigravity/HyperSynergism/synergism-hypersynergy/src/mod/class/hs-modules/hs-heater/temp-helper-files/heater_compare.js")
print('Running:', script)
result = subprocess.run(['node', str(script)], capture_output=True, text=True)
print('RETURN CODE:', result.returncode)
print(result.stdout)
print(result.stderr)
# Out:
# Running: c:\Users\tangu\Documents\Antigravity\HyperSynergism\synergism-hypersynergy\src\mod\class\hs-modules\hs-heater\temp-helper-files\heater_compare.js
# RETURN CODE: 0
# Spreadsheet comparison rows for target labels:
# ---
# Row 25, Col 1, Label: Voucher, Field: voucher
# First numeric after label: 364
# Tail values: [364,null,null,"S2: Max SR2",null,"Outside Exalt",null,null,null,"N/A"]
# ---
# Row 26, Col 1, Label: Base Obtainium, Field: baseobt
# First numeric after label: 15
# Tail values: [15,null,null,"Amb + Oct (Only use when Max Luck):",null,null,null,null,null,null]
# ---
# Row 27, Col 1, Label: Base Offering, Field: baseoff
# First numeric after label: 15
# Tail values: [15,null,null,"Types","Active?","Loadout","Cost","Effect",null,null]
# ---
# Row 28, Col 1, Label: Blueberries, Field: blueberries
# First numeric after label: 97285601
# ...

# %%
import subprocess
from pathlib import Path

script_dir = Path(r"c:/Users/tangu/Documents/Antigravity/HyperSynergism/synergism-hypersynergy/src/mod/class/hs-modules/hs-heater/temp-helper-files")
workbook_path = script_dir.parent.parent.parent.parent.parent.parent / 'docs' / 'SynergismOfficial-master' / 'Re-Octptimisation (Beta 1.2.5E)' / 'Re-Octptimisation (Beta 1.2.5E).xlsx'
js = f"""
const xlsx = require('xlsx');
const path = require('path');
const wb = xlsx.readFile({json.dumps(str(workbook_path))});
console.log('sheets=' + JSON.stringify(wb.SheetNames));
"""
result = subprocess.run(['node', '-e', js], capture_output=True, text=True)
print('RETURN CODE:', result.returncode)
print(result.stdout)
print(result.stderr)
# Out:
# RETURN CODE: 0
# sheets=["Main","Changelog","Save File Input","True Ambrosia Heater","Hept Optimisation","Spreadsheet Tutorial","Sheet40","GQ-CDE","Formatting","Octptimisation","Citadel Of Spreadsheet","Post P4x4 Optimisation (phased ","Endgame Optimisation","Corruption Calculation","Infinite WOW","Cubes in s0","Golden Quark Metagenesis","Token Buff Calculator","Runes Level Calculator","Singularity Debuff","Misc. Effect to Hept ref. table","S0 Quark Shop","Singularity Quark Buff","SLAE","Quark","Quack","Quack Lookup-Table","Daily Quark Tracking","Octeract Metagenesis","e7x20 Upgrade Effect Calculatio","Government Simulator","Ambrosia Ambacus","Infinite+ Ambrosia","Infinite Ambrosia","A0 Optimiser","A0 testing area","felt mathy, might delete later","Testing Area For Stronger Multi","TAFSM Quark Oct Edition","TAFSM GQ_DEFAULT Edition"]

# %%
import subprocess
from pathlib import Path

script_dir = Path(r"c:/Users/tangu/Documents/Antigravity/HyperSynergism/synergism-hypersynergy/src/mod/class/hs-modules/hs-heater/temp-helper-files")
workbook_path = script_dir.parent.parent.parent.parent.parent.parent / 'docs' / 'SynergismOfficial-master' / 'Re-Octptimisation (Beta 1.2.5E)' / 'Re-Octptimisation (Beta 1.2.5E).xlsx'
js_path = script_dir / 'heater_compare_scan.js'
js_code = (
    "const xlsx = require('xlsx');\n"
    + "const workbook = xlsx.readFile(" + repr(str(workbook_path).replace('\\', '\\\\')) + ");\n"
    + "const sheet = workbook.Sheets['True Ambrosia Heater'];\n"
    + "const range = xlsx.utils.decode_range(sheet['!ref']);\n"
    + "const terms = ['asc', 'speed', 'Ascension', 'ascSpeed', 'Speed'];\n"
    + "for (let r = range.s.r; r <= range.e.r; ++r) {\n"
    + "    let row = [];\n"
    + "    for (let c = range.s.c; c <= range.e.c; ++c) {\n"
    + "        const addr = xlsx.utils.encode_cell({ r, c });\n"
    + "        const cell = sheet[addr];\n"
    + "        if (!cell) row.push(null);\n"
    + "        else if (cell.f) row.push(`f:${cell.f}`);\n"
    + "        else row.push(cell.v);\n"
    + "    }\n"
    + "    const flat = row.filter(v => typeof v === 'string');\n"
    + "    if (flat.some(v => terms.some(t => v.toLowerCase().includes(t.toLowerCase())))) {\n"
    + "        console.log('ROW', r + 1, JSON.stringify(row.slice(0, 20)));\n"
    + "    }\n"
    + "}\n"
)
js_path.write_text(js_code, encoding='utf-8')
result = subprocess.run(['node', str(js_path)], capture_output=True, text=True)
print('JS file:', js_path)
print('RETURN CODE:', result.returncode)
print(result.stdout)
print(result.stderr)
# Out:
# JS file: c:\Users\tangu\Documents\Antigravity\HyperSynergism\synergism-hypersynergy\src\mod\class\hs-modules\hs-heater\temp-helper-files\heater_compare_scan.js
# RETURN CODE: 0
# ...

# %%
import subprocess
from pathlib import Path
import json

script_dir = Path(r"c:/Users/tangu/Documents/Antigravity/HyperSynergism/synergism-hypersynergy/src/mod/class/hs-modules/hs-heater/temp-helper-files")
workbook_path = script_dir.parent.parent.parent.parent.parent.parent / 'docs' / 'SynergismOfficial-master' / 'Re-Octptimisation (Beta 1.2.5E)' / 'Re-Octptimisation (Beta 1.2.5E).xlsx'
js = """
const xlsx = require('xlsx');
const wb = xlsx.readFile(%s);
const sheet = wb.Sheets['True Ambrosia Heater'];
const range = xlsx.utils.decode_range(sheet['!ref']);
for (let r = 20; r <= 45; ++r) {
    const row = [];
    for (let c = range.s.c; c <= range.e.c && c < range.s.c + 25; ++c) {
        const addr = xlsx.utils.encode_cell({r, c});
        const cell = sheet[addr];
        if (!cell) row.push(null);
        else if (cell.f) row.push(`f:${cell.f}`);
        else row.push(cell.v);
    }
    console.log('ROW', r + 1, JSON.stringify(row));
}
""" % json.dumps(str(workbook_path))
result = subprocess.run(['node', '-e', js], capture_output=True, text=True)
print('RETURN CODE:', result.returncode)
print(result.stdout)
print(result.stderr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 18
#      14     for (let c = range.s.c; c <= range.e.c && c < range.s.c + 25; ++c) {{
#      15         const addr = xlsx.utils.encode_cell({{r, c}});
#      16         const cell = sheet[addr];
#      17         if (!cell) row.push(null);
# ---> 18         else if (cell.f) row.push(`f:${cell.f}`);
#      19         else row.push(cell.v);
#      20     }}
#      21     console.log('ROW', r + 1, JSON.stringify(row));
#
# NameError: name 'cell' is not defined

# %%
import xlsx
from pathlib import Path
script_dir = Path(r"c:/Users/tangu/Documents/Antigravity/HyperSynergism/synergism-hypersynergy/src/mod/class/hs-modules/hs-heater/temp-helper-files")
wb_path = script_dir.parent.parent.parent.parent.parent.parent / 'docs' / 'SynergismOfficial-master' / 'Re-Octptimisation (Beta 1.2.5E)' / 'Re-Octptimisation (Beta 1.2.5E).xlsx'
print('Workbook path:', wb_path)

workbook = xlsx.read_workbook(str(wb_path))
print('Sheet names:', workbook.sheet_names)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 import xlsx
#       2 from pathlib import Path
#       3 script_dir = Path(r"c:/Users/tangu/Documents/Antigravity/HyperSynergism/synergism-hypersynergy/src/mod/class/hs-modules/hs-heater/temp-helper-files")
#       4 wb_path = script_dir.parent.parent.parent.parent.parent.parent / 'docs' / 'SynergismOfficial-master' / 'Re-Octptimisation (Beta 1.2.5E)' / 'Re-Octptimisation (Beta 1.2.5E).xlsx'
#
# ModuleNotFoundError: No module named 'xlsx'

# %%
import openpyxl
print('openpyxl', openpyxl.__version__)
# Out:
# openpyxl 3.1.5

# %%
from pathlib import Path
import openpyxl

script_dir = Path(r"c:/Users/tangu/Documents/Antigravity/HyperSynergism/synergism-hypersynergy/src/mod/class/hs-modules/hs-heater/temp-helper-files")
workbook_path = script_dir.parents[5] / 'docs' / 'SynergismOfficial-master' / 'Re-Octptimisation (Beta 1.2.5E)' / 'Re-Octptimisation (Beta 1.2.5E).xlsx'
print('workbook_path:', workbook_path)
wb = openpyxl.load_workbook(workbook_path, data_only=True, read_only=True)
print('sheets:', wb.sheetnames)
sheet = wb['True Ambrosia Heater']
for r in range(20, 46):
    values = [sheet.cell(row=r, column=c).value for c in range(1, 26)]
    print('ROW', r, values)
# Out:
# workbook_path: c:\Users\tangu\Documents\Antigravity\HyperSynergism\synergism-hypersynergy\docs\SynergismOfficial-master\Re-Octptimisation (Beta 1.2.5E)\Re-Octptimisation (Beta 1.2.5E).xlsx
# ...

# %%
from pathlib import Path
import openpyxl

script_dir = Path(r"c:/Users/tangu/Documents/Antigravity/HyperSynergism/synergism-hypersynergy/src/mod/class/hs-modules/hs-heater/temp-helper-files")
workbook_path = script_dir.parents[5] / 'docs' / 'SynergismOfficial-master' / 'Re-Octptimisation (Beta 1.2.5E)' / 'Re-Octptimisation (Beta 1.2.5E).xlsx'
wb = openpyxl.load_workbook(workbook_path, data_only=True, read_only=True)
sheet = wb['True Ambrosia Heater']
for r, row in enumerate(sheet.iter_rows(min_row=1, max_col=15, values_only=True), start=1):
    first_col = str(row[0] or '')
    if any(keyword in first_col.lower() for keyword in ['asc', 'speed', 'ascension', 's1', 's2', 'sr2']):
        print('ROW', r, list(row))
# Out:
# ROW 22 ['Asc. Speed (C)', 4.397851798776171e+50, None, None, 'H6', None, '{"ambrosiaTutorial":10,"ambrosiaPatreon":1,"ambrosiaObtainium1":0,"ambrosiaOffering1":0,"ambrosiaHyperflux":6,"ambrosiaQuarks1":20,"ambrosiaCubes1":100,"ambrosiaLuck1":40,"ambrosiaCubeQuark1":0,"ambrosiaLuckQuark1":0,"ambrosiaLuckCube1":16,"ambrosiaQuarkCube1":16,"ambrosiaCubeLuck1":1,"ambrosiaQuarkLuck1":6,"ambrosiaQuarks2":0,"ambrosiaCubes2":100,"ambrosiaLuck2":15,"ambrosiaQuarks3":0,"ambrosiaCubes3":32,"ambrosiaLuck3":0,"ambrosiaBaseObtainium1":15,"ambrosiaBaseOffering1":30,"ambrosiaBaseObtainium2":10,"ambrosiaBaseOffering2":20,"ambrosiaSingReduction1":2,"ambrosiaSingReduction2":0,"ambrosiaInfiniteShopUpgrades1":20,"ambrosiaInfiniteShopUpgrades2":12,"ambrosiaLuck4":0,"ambrosiaTalismanBonusRuneLevel":10,"ambrosiaRuneOOMBonus":0}', None, 26078041.0, None, 1089880588673.9988, 17.0, False, None, 'Shop Speed 1']
# ...

# %%
from pathlib import Path
import openpyxl
script_dir = Path(r"c:/Users/tangu/Documents/Antigravity/HyperSynergism/synergism-hypersynergy/src/mod/class/hs-modules/hs-heater/temp-helper-files")
workbook_path = script_dir.parents[5] / 'docs' / 'SynergismOfficial-master' / 'Re-Octptimisation (Beta 1.2.5E)' / 'Re-Octptimisation (Beta 1.2.5E).xlsx'
wb = openpyxl.load_workbook(workbook_path, data_only=False, read_only=True)
sheet = wb['True Ambrosia Heater']
for r in range(1, 26):
    values = [sheet.cell(row=r, column=c).value for c in range(1, 6)]
    if any(values):
        print('ROW', r, values)
# Out:
# ROW 1 ['True Ambrosia Heater (An Ambrosia Optimiser)', None, None, None, None]
# ROW 4 ["This sheet DOESN'T uses greedy algorithm for optimisation.", None, None, None, 'Common Loadouts:']
# ROW 5 ['Lifetime Ambrosia', 26078237.0, None, None, 'Types']
# ROW 6 ['Quarks', 6.829347764977701e+27, None, None, 'C1: Quarks']
# ROW 7 ['Platonic Upgrade 4x4', 0.0, "Press the button below to start calculator (If you don't see it, it is a google sheet problem)", None, 'C2: 3-7D Cubes']
# ROW 8 ['Base Luck', 4642.3120244385, None, None, 'C3: Octeracts']
# ROW 9 ['Base Luck Multiplier', 0.32450000000000023, None, None, 'C4: Luck']
# ROW 10 ['Check if using sum', True, None, None, 'A0 Loadouts:']
# ROW 11 ['Cubes exp', 22.20494365147817, None, None, 'Types']
# ROW 12 ['Tesseracts exp', 16.421965972609126, None, None, 'A1: Obtainium']
# ROW 13 ['Hypercubes exp', 20.163352156197547, None, None, 'A2: Offering']
# ...

# %%
from pathlib import Path
import openpyxl
script_dir = Path(r"c:/Users/tangu/Documents/Antigravity/HyperSynergism/synergism-hypersynergy/src/mod/class/hs-modules/hs-heater/temp-helper-files")
workbook_path = script_dir.parents[5] / 'docs' / 'SynergismOfficial-master' / 'Re-Octptimisation (Beta 1.2.5E)' / 'Re-Octptimisation (Beta 1.2.5E).xlsx'
wb = openpyxl.load_workbook(workbook_path, data_only=False, read_only=True)
sheet = wb['True Ambrosia Heater']
for r in [22, 23, 24, 25]:
    row = [sheet.cell(row=r, column=c) for c in range(1, 11)]
    print('ROW', r)
    for c, cell in enumerate(row, start=1):
        print('  C', c, 'val=', cell.value, 'type=', cell.data_type)
# Out:
# ROW 22
#   C 1 val= Asc. Speed (C) type= s
#   C 2 val= 4.397851798776171e+50 type= n
#   C 3 val= None type= n
#   C 4 val= None type= n
#   C 5 val= H6 type= s
#   C 6 val= None type= n
#   C 7 val= {"ambrosiaTutorial":10,"ambrosiaPatreon":1,"ambrosiaObtainium1":0,"ambrosiaOffering1":0,"ambrosiaHyperflux":6,"ambrosiaQuarks1":20,"ambrosiaCubes1":100,"ambrosiaLuck1":40,"ambrosiaCubeQuark1":0,"ambrosiaLuckQuark1":0,"ambrosiaLuckCube1":16,"ambrosiaQuarkCube1":16,"ambrosiaCubeLuck1":1,"ambrosiaQuarkLuck1":6,"ambrosiaQuarks2":0,"ambrosiaCubes2":100,"ambrosiaLuck2":15,"ambrosiaQuarks3":0,"ambrosiaCubes3":32,"ambrosiaLuck3":0,"ambrosiaBaseObtainium1":15,"ambrosiaBaseOffering1":30,"ambrosiaBaseObtainium2":10,"ambrosiaBaseOffering2":20,"ambrosiaSingReduction1":2,"ambrosiaSingReduction2":0,"ambrosiaInfiniteShopUpgrades1":20,"ambrosiaInfiniteShopUpgrades2":12,"ambrosiaLuck4":0,"ambrosiaTalismanBonusRuneLevel":10,"ambrosiaRuneOOMBonus":0} type= s
#   C 8 val= None type= n
# ...

# %%
import subprocess
result = subprocess.run(['node', '-e', 'console.log(process.version)'], capture_output=True, text=True)
print(result.returncode)
print(result.stdout)
print(result.stderr)
# Out:
# 0
# v24.12.0

# %%
import subprocess
import pathlib
root = pathlib.Path(r"c:/Users/tangu/Documents/Antigravity/HyperSynergism/synergism-hypersynergy")
script = """
const mod = require('./build/hypersynergism.js');
console.log('mod keys', Object.keys(mod));
if (mod && mod.default) console.log('default keys', Object.keys(mod.default));
"""
result = subprocess.run(['node', '-e', script], cwd=str(root), capture_output=True, text=True)
print(result.returncode)
print(result.stdout)
print(result.stderr)
# Out:
# 1
#
# c:\Users\tangu\Documents\Antigravity\HyperSynergism\synergism-hypersynergy\build\hypersynergism.js:4709
#         isDev: window.__HS_IS_DEV ? window.__HS_IS_DEV : false,
#                ^
#
# ReferenceError: window is not defined
#     at <static_initializer> (c:\Users\tangu\Documents\Antigravity\HyperSynergism\synergism-hypersynergy\build\hypersynergism.js:4709:16)
#     at c:\Users\tangu\Documents\Antigravity\HyperSynergism\synergism-hypersynergy\build\hypersynergism.js:4677:18
#     at Object.<anonymous> (c:\Users\tangu\Documents\Antigravity\HyperSynergism\synergism-hypersynergy\build\hypersynergism.js:33361:3)
#     at Module._compile (node:internal/modules/cjs/loader:1761:14)
#     at Object..js (node:internal/modules/cjs/loader:1893:10)
#     at Module.load (node:internal/modules/cjs/loader:1481:32)
#     at Module._load (node:internal/modules/cjs/loader:1300:12)
#     at TracingChannel.traceSync (node:diagnostics_channel:328:14)
# ...

# %%
import subprocess
import pathlib
root = pathlib.Path(r"c:/Users/tangu/Documents/Antigravity/HyperSynergism/synergism-hypersynergy")
script = '''global.window = { __HS_IS_DEV: false, location: { href: "" }, document: null };
global.document = { getElementById: () => null, querySelector: () => null, createElement: () => ({ style: {} }), body: { appendChild: () => {} } };
global.navigator = { userAgent: 'node' };
const mod = require('./build/hypersynergism.js');
console.log('loaded');
console.log('keys', Object.keys(mod));
'''
result = subprocess.run(['node', '-e', script], cwd=str(root), capture_output=True, text=True)
print(result.returncode)
print(result.stdout)
print(result.stderr)
# Out:
# 1
# [HSModuleManager]: Enabling Hypersynergism modules
# loaded
# keys []
# [HSMain]: Initialising Hypersynergism modules
# [HSPrototypes]: Enabled module 'HSPrototypes'
# [HSPrototypes]: Extending native prototypes with extra functionality
#
# [HSMain]: Hypersynergism: Game load timed out, attempting init anyway...
# c:\Users\tangu\Documents\Antigravity\HyperSynergism\synergism-hypersynergy\build\hypersynergism.js:13151
#       Element.prototype.delegateEventListener = this.#createDelegateEventListener();
#       ^
#
# ReferenceError: Element is not defined
#     at HSPrototypes.init (c:\Users\tangu\Documents\Antigravity\HyperSynergism\synergism-hypersynergy\build\hypersynergism.js:13151:7)
#     at _HSModuleManager.preprocessModules (c:\Users\tangu\Documents\Antigravity\HyperSynergism\synergism-hypersynergy\build\hypersynergism.js:32012:26)
# ...

# %%
import subprocess
import pathlib
root = pathlib.Path(r"c:/Users/tangu/Documents/Antigravity/HyperSynergism/synergism-hypersynergy")
result = subprocess.run(['npm', '--version'], cwd=str(root), capture_output=True, text=True)
print(result.returncode)
print(result.stdout)
print(result.stderr)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 4
#       1 import subprocess
#       2 import pathlib
#       3 root = pathlib.Path(r"c:/Users/tangu/Documents/Antigravity/HyperSynergism/synergism-hypersynergy")
# ----> 4 result = subprocess.run(['npm', '--version'], cwd=str(root), capture_output=True, text=True)
#       5 print(result.returncode)
#       6 print(result.stdout)
#       7 print(result.stderr)
#
# File ~\AppData\Roaming\uv\python\cpython-3.14.4-windows-x86_64-none\Lib\subprocess.py:555, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     552     kwargs['stdout'] = PIPE
#     553     kwargs['stderr'] = PIPE
# --> 555 with Popen(*popenargs, **kwargs) as process:
#     556     try:
#     557         stdout, stderr = process.communicate(input, timeout=timeout)
#
# ...

# %%
import subprocess
import pathlib
root = pathlib.Path(r"c:/Users/tangu/Documents/Antigravity/HyperSynergism/synergism-hypersynergy")
script = '''
globalThis.window = {
  __HS_IS_DEV: false,
  location: { href: '' },
  addEventListener: () => {},
  removeEventListener: () => {},
  requestAnimationFrame: (cb) => setTimeout(cb, 0),
  cancelAnimationFrame: () => {},
  getComputedStyle: () => ({}),
  innerWidth: 1000,
  innerHeight: 800,
};
globalThis.document = {
  getElementById: () => null,
  querySelector: () => null,
  querySelectorAll: () => [],
  createElement: (tag) => ({
    tagName: String(tag).toUpperCase(),
    style: {},
    addEventListener: () => {},
    removeEventListener: () => {},
    appendChild: () => {},
    setAttribute: () => {},
    getContext: () => ({}),
    innerHTML: '',
    classList: { add: () => {}, remove: () => {}, contains: () => false },
    value: '',
  }),
  body: { appendChild: () => {}, removeChild: () => {}, style: {} },
  createTextNode: (text) => ({ textContent: text }),
  documentElement: { style: {} },
  addEventListener: () => {},
  removeEventListener: () => {},
};
globalThis.Element = function() {};
globalThis.Element.prototype = {};
globalThis.HTMLElement = globalThis.Element;
globalThis.Node = function() {};
globalThis.Event = function(type, init = {}) { this.type = type; this.detail = init.detail; };
globalThis.CustomEvent = globalThis.Event;
globalThis.MouseEvent = globalThis.Event;
globalThis.KeyboardEvent = globalThis.Event;
globalThis.navigator = { userAgent: 'node' };
require('./build/hypersynergism.js');
console.log('bundle loaded');
'''
result = subprocess.run(['node', '-e', script], cwd=str(root), capture_output=True, text=True)
print(result.returncode)
print(result.stdout)
print(result.stderr)
# Out:
# 1
# [HSModuleManager]: Enabling Hypersynergism modules
# bundle loaded
# [HSMain]: Initialising Hypersynergism modules
# [HSPrototypes]: Enabled module 'HSPrototypes'
# [HSPrototypes]: Extending native prototypes with extra functionality
#
# [HSMain]: Hypersynergism: Game load timed out, attempting init anyway...
# c:\Users\tangu\Documents\Antigravity\HyperSynergism\synergism-hypersynergy\build\hypersynergism.js:13152
#       Document.prototype.delegateEventListener = this.#createDelegateEventListener();
#       ^
#
# ReferenceError: Document is not defined
#     at HSPrototypes.init (c:\Users\tangu\Documents\Antigravity\HyperSynergism\synergism-hypersynergy\build\hypersynergism.js:13152:7)
#     at _HSModuleManager.preprocessModules (c:\Users\tangu\Documents\Antigravity\HyperSynergism\synergism-hypersynergy\build\hypersynergism.js:32012:26)
# ...

# %%
import subprocess
import pathlib
root = pathlib.Path(r"c:/Users/tangu/Documents/Antigravity/HyperSynergism/synergism-hypersynergy")
script = '''
globalThis.window = {
  __HS_IS_DEV: false,
  location: { href: '' },
  addEventListener: () => {},
  removeEventListener: () => {},
  requestAnimationFrame: (cb) => setTimeout(cb, 0),
  cancelAnimationFrame: () => {},
  getComputedStyle: () => ({}),
  innerWidth: 1000,
  innerHeight: 800,
};
globalThis.document = {
  getElementById: () => null,
  querySelector: () => null,
  querySelectorAll: () => [],
  createElement: (tag) => ({
    tagName: String(tag).toUpperCase(),
    style: {},
    addEventListener: () => {},
    removeEventListener: () => {},
    appendChild: () => {},
    setAttribute: () => {},
    getContext: () => ({}),
    innerHTML: '',
    classList: { add: () => {}, remove: () => {}, contains: () => false },
    value: '',
  }),
  body: { appendChild: () => {}, removeChild: () => {}, style: {} },
  createTextNode: (text) => ({ textContent: text }),
  documentElement: { style: {} },
  addEventListener: () => {},
  removeEventListener: () => {},
};
globalThis.Element = function() {};
globalThis.Element.prototype = {};
globalThis.Document = function() {};
globalThis.Document.prototype = {};
globalThis.HTMLElement = globalThis.Element;
globalThis.Node = function() {};
globalThis.Event = function(type, init = {}) { this.type = type; this.detail = init.detail; };
globalThis.CustomEvent = globalThis.Event;
globalThis.MouseEvent = globalThis.Event;
globalThis.KeyboardEvent = globalThis.Event;
globalThis.navigator = { userAgent: 'node' };
require('./build/hypersynergism.js');
console.log('bundle loaded');
'''
result = subprocess.run(['node', '-e', script], cwd=str(root), capture_output=True, text=True)
print(result.returncode)
print(result.stdout)
print(result.stderr)
# Out:
# 1
# [HSModuleManager]: Enabling Hypersynergism modules
# bundle loaded
# [HSMain]: Initialising Hypersynergism modules
# [HSPrototypes]: Enabled module 'HSPrototypes'
# [HSPrototypes]: Extending native prototypes with extra functionality
# [HSUI]: Enabled module 'HSUI'
# [HSUI]: Initialising HSUI module
#
# [HSMain]: Hypersynergism: Game load timed out, attempting init anyway...
# c:\Users\tangu\Documents\Antigravity\HyperSynergism\synergism-hypersynergy\build\hypersynergism.js:6498
#       document.head.appendChild(_HSUI.#injectedStylesHolder);
#                     ^
#
# TypeError: Cannot read properties of undefined (reading 'appendChild')
#     at #initializePanelMarkup (c:\Users\tangu\Documents\Antigravity\HyperSynergism\synergism-hypersynergy\build\hypersynergism.js:6498:21)
#     at _HSUI.init (c:\Users\tangu\Documents\Antigravity\HyperSynergism\synergism-hypersynergy\build\hypersynergism.js:6487:40)
# ...

# %%
import subprocess
import pathlib
root = pathlib.Path(r"c:/Users/tangu/Documents/Antigravity/HyperSynergism/synergism-hypersynergy")
script = '''
globalThis.window = {
  __HS_IS_DEV: false,
  location: { href: '' },
  addEventListener: () => {},
  removeEventListener: () => {},
  requestAnimationFrame: (cb) => setTimeout(cb, 0),
  cancelAnimationFrame: () => {},
  getComputedStyle: () => ({}),
  innerWidth: 1000,
  innerHeight: 800,
};
globalThis.document = {
  getElementById: () => null,
  querySelector: () => null,
  querySelectorAll: () => [],
  createElement: (tag) => ({
    tagName: String(tag).toUpperCase(),
    style: {},
    addEventListener: () => {},
    removeEventListener: () => {},
    appendChild: () => {},
    removeChild: () => {},
    setAttribute: () => {},
    getContext: () => ({}),
    innerHTML: '',
    classList: { add: () => {}, remove: () => {}, contains: () => false },
    value: '',
  }),
  body: { appendChild: () => {}, removeChild: () => {}, style: {} },
  head: { appendChild: () => {}, removeChild: () => {} },
  createTextNode: (text) => ({ textContent: text }),
  documentElement: { style: {} },
  addEventListener: () => {},
  removeEventListener: () => {},
};
globalThis.Element = function() {};
globalThis.Element.prototype = {};
globalThis.Document = function() {};
globalThis.Document.prototype = {};
globalThis.HTMLElement = globalThis.Element;
globalThis.Node = function() {};
globalThis.Event = function(type, init = {}) { this.type = type; this.detail = init.detail; };
globalThis.CustomEvent = globalThis.Event;
globalThis.MouseEvent = globalThis.Event;
globalThis.KeyboardEvent = globalThis.Event;
globalThis.navigator = { userAgent: 'node' };
require('./build/hypersynergism.js');
console.log('bundle loaded');
'''
result = subprocess.run(['node', '-e', script], cwd=str(root), capture_output=True, text=True)
print(result.returncode)
print(result.stdout)
print(result.stderr)
# Out:
# 1
# [HSModuleManager]: Enabling Hypersynergism modules
# bundle loaded
# [HSMain]: Initialising Hypersynergism modules
# [HSPrototypes]: Enabled module 'HSPrototypes'
# [HSPrototypes]: Extending native prototypes with extra functionality
# [HSUI]: Enabled module 'HSUI'
# [HSUI]: Initialising HSUI module
#
# [HSMain]: Hypersynergism: Game load timed out, attempting init anyway...
# [HSElementHooker]: Hook timed out
# [HSUtils]: Get operation intercepted by Null Proxy 'ElementHookTimeout', something is not right
# [HSElementHooker]: Hook timed out
# [HSUtils]: Get operation intercepted by Null Proxy 'ElementHookTimeout', something is not right
# [HSElementHooker]: Hook timed out
# [HSUtils]: Get operation intercepted by Null Proxy 'ElementHookTimeout', something is not right
# [HSElementHooker]: Hook timed out
# [HSUtils]: Get operation intercepted by Null Proxy 'ElementHookTimeout', something is not right
# [HSElementHooker]: Hook timed out
# ...

# %%
import subprocess
import pathlib
root = pathlib.Path(r"c:/Users/tangu/Documents/Antigravity/HyperSynergism/synergism-hypersynergy")
script = '''
Object.prototype.addEventListener = function() {};
Object.prototype.removeEventListener = function() {};
Object.prototype.setAttribute = function() {};
class Element {
  constructor() {
    this.style = {};
    this.classList = { add: () => {}, remove: () => {}, contains: () => false };
    this.children = [];
    this.value = '';
    this.innerHTML = '';
    this.textContent = '';
  }
  addEventListener() {}
  removeEventListener() {}
  appendChild(child) { this.children.push(child); return child; }
  removeChild() {}
  setAttribute() {}
  getContext() { return {}; }
  querySelector() { return null; }
  querySelectorAll() { return []; }
}
class Document {
  constructor() {
    this.body = new Element();
    this.head = new Element();
    this.documentElement = new Element();
  }
  getElementById() { return null; }
  querySelector() { return null; }
  querySelectorAll() { return []; }
  createElement(tag) { return new Element(); }
  createTextNode(text) { return { textContent: text }; }
  addEventListener() {}
  removeEventListener() {}
}
globalThis.window = {
  __HS_IS_DEV: false,
  location: { href: '' },
  addEventListener: () => {},
  removeEventListener: () => {},
  requestAnimationFrame: (cb) => setTimeout(cb, 0),
  cancelAnimationFrame: () => {},
  getComputedStyle: () => ({}),
  innerWidth: 1000,
  innerHeight: 800,
};
globalThis.document = new Document();
globalThis.Element = Element;
globalThis.HTMLElement = Element;
globalThis.Document = Document;
globalThis.Node = function() {};
globalThis.Event = function(type, init = {}) { this.type = type; this.detail = init.detail; };
globalThis.CustomEvent = globalThis.Event;
globalThis.MouseEvent = globalThis.Event;
globalThis.KeyboardEvent = globalThis.Event;
globalThis.navigator = { userAgent: 'node' };
globalThis.location = globalThis.window.location;
require('./build/hypersynergism.js');
console.log('bundle loaded');
'''
result = subprocess.run(['node', '-e', script], cwd=str(root), capture_output=True, text=True)
print(result.returncode)
print(result.stdout)
print(result.stderr)
# Out:
# 1
# [HSModuleManager]: Enabling Hypersynergism modules
# bundle loaded
# [HSMain]: Initialising Hypersynergism modules
# [HSPrototypes]: Enabled module 'HSPrototypes'
# [HSPrototypes]: Extending native prototypes with extra functionality
# [HSUI]: Enabled module 'HSUI'
# [HSUI]: Initialising HSUI module
#
# [HSMain]: Hypersynergism: Game load timed out, attempting init anyway...
# [HSElementHooker]: Hook timed out
# [HSUtils]: Get operation intercepted by Null Proxy 'ElementHookTimeout', something is not right
# [HSElementHooker]: Hook timed out
# [HSUtils]: Get operation intercepted by Null Proxy 'ElementHookTimeout', something is not right
# [HSElementHooker]: Hook timed out
# [HSUtils]: Get operation intercepted by Null Proxy 'ElementHookTimeout', something is not right
# [HSElementHooker]: Hook timed out
# [HSUtils]: Get operation intercepted by Null Proxy 'ElementHookTimeout', something is not right
# [HSElementHooker]: Hook timed out
# ...

# %%
from pathlib import Path
import openpyxl

labels = [
    'SI Non-Amb RC',
    'Bonus SI',
    'Bonus IA (total)',
    'Bonus IA (from talisman)',
    'Base Talisman Power',
    'Blueberries',
    'Base Obtainium',
    'Base Offering',
    'Voucher',
    'Asc. Speed (C)',
    'Ascension Speed (H)',
    'Spread'
]

script_dir = Path(r"c:/Users/tangu/Documents/Antigravity/HyperSynergism/synergism-hypersynergy/src/mod/class/hs-modules/hs-heater/temp-helper-files")
workbook_path = script_dir.parents[5] / 'docs' / 'SynergismOfficial-master' / 'Re-Octptimisation (Beta 1.2.5E)' / 'Re-Octptimisation (Beta 1.2.5E).xlsx'
wb = openpyxl.load_workbook(workbook_path, data_only=True, read_only=True)
sheet = wb['True Ambrosia Heater']
for row_index, row in enumerate(sheet.iter_rows(values_only=True), start=1):
    label = str(row[0]).strip() if row[0] is not None else ''
    if label in labels:
        print('ROW', row_index, label, [row[i] if i < len(row) else None for i in range(0, 12)])
# Out:
# ROW 22 Asc. Speed (C) ['Asc. Speed (C)', 4.397851798776171e+50, None, None, 'H6', None, '{"ambrosiaTutorial":10,"ambrosiaPatreon":1,"ambrosiaObtainium1":0,"ambrosiaOffering1":0,"ambrosiaHyperflux":6,"ambrosiaQuarks1":20,"ambrosiaCubes1":100,"ambrosiaLuck1":40,"ambrosiaCubeQuark1":0,"ambrosiaLuckQuark1":0,"ambrosiaLuckCube1":16,"ambrosiaQuarkCube1":16,"ambrosiaCubeLuck1":1,"ambrosiaQuarkLuck1":6,"ambrosiaQuarks2":0,"ambrosiaCubes2":100,"ambrosiaLuck2":15,"ambrosiaQuarks3":0,"ambrosiaCubes3":32,"ambrosiaLuck3":0,"ambrosiaBaseObtainium1":15,"ambrosiaBaseOffering1":30,"ambrosiaBaseObtainium2":10,"ambrosiaBaseOffering2":20,"ambrosiaSingReduction1":2,"ambrosiaSingReduction2":0,"ambrosiaInfiniteShopUpgrades1":20,"ambrosiaInfiniteShopUpgrades2":12,"ambrosiaLuck4":0,"ambrosiaTalismanBonusRuneLevel":10,"ambrosiaRuneOOMBonus":0}', None, 26078041.0, None, 1089880588673.9988, 17.0]
# ...

# %%
from pathlib import Path
import openpyxl

labels = [
    'SI Non-Amb RC',
    'Bonus SI',
    'Bonus IA (total)',
    'Bonus IA (from talisman)',
    'Base Talisman Power',
    'Blueberries',
    'Base Obtainium',
    'Base Offering',
    'Voucher',
    'Asc. Speed (C)',
    'Ascension Speed (H)',
    'Spread'
]

script_dir = Path(r"c:/Users/tangu/Documents/Antigravity/HyperSynergism/synergism-hypersynergy/src/mod/class/hs-modules/hs-heater/temp-helper-files")
workbook_path = script_dir.parents[5] / 'docs' / 'SynergismOfficial-master' / 'Re-Octptimisation (Beta 1.2.5E)' / 'Re-Octptimisation (Beta 1.2.5E).xlsx'
wb = openpyxl.load_workbook(workbook_path, data_only=True, read_only=True)
sheet = wb['True Ambrosia Heater']
for row_index, row in enumerate(sheet.iter_rows(values_only=True), start=1):
    label = str(row[0]).strip() if row[0] is not None else ''
    if label in labels:
        print('ROW', row_index, label, 'value=', row[1], 'ref=', row[4])
# Out:
# ROW 22 Asc. Speed (C) value= 4.397851798776171e+50 ref= H6
# ROW 23 Ascension Speed (H) value= 4.4864766093719e-16 ref= H7
# ROW 24 Spread value= 0.094 ref= S1: Max SR1
# ROW 25 Voucher value= 364.0 ref= S2: Max SR2
# ROW 26 Base Obtainium value= 15.0 ref= Amb + Oct (Only use when Max Luck):
# ROW 27 Base Offering value= 15.0 ref= Types
# ROW 28 Blueberries value= 25 ref= M0: Max Luck
# ROW 35 SI Non-Amb RC value= 211.8 ref= None
# ROW 36 Bonus SI value= 118500.0 ref= None
# ROW 37 Bonus IA (total) value= 93.48 ref= None
# ROW 38 Bonus IA (from talisman) value= 71.479 ref= None
# ROW 39 Base Talisman Power value= 2.216 ref= None

# %%
import subprocess
import pathlib
root = pathlib.Path(r"c:/Users/tangu/Documents/Antigravity/HyperSynergism/synergism-hypersynergy")
script = '''
class Element {
  constructor() {
    this.style = {};
    this.classList = { add: () => {}, remove: () => {}, contains: () => false };
    this.children = [];
    this.value = '';
    this.innerHTML = '';
    this.textContent = '';
  }
  addEventListener() {}
  removeEventListener() {}
  appendChild(child) { this.children.push(child); return child; }
  removeChild() {}
  setAttribute() {}
  getContext() { return {}; }
  querySelector() { return null; }
  querySelectorAll() { return []; }
}
class Document {
  constructor() {
    this.body = new Element();
    this.head = new Element();
    this.documentElement = new Element();
  }
  getElementById() { return null; }
  querySelector() { return null; }
  querySelectorAll() { return []; }
  createElement(tag) { return new Element(); }
  createTextNode(text) { return { textContent: text }; }
  addEventListener() {}
  removeEventListener() {}
}
globalThis.window = {
  __HS_IS_DEV: false,
  location: { href: '' },
  addEventListener: () => {},
  removeEventListener: () => {},
  requestAnimationFrame: (cb) => setTimeout(cb, 0),
  cancelAnimationFrame: () => {},
  getComputedStyle: () => ({}),
  innerWidth: 1000,
  innerHeight: 800,
};
globalThis.document = new Document();
globalThis.Element = Element;
globalThis.HTMLElement = Element;
globalThis.Document = Document;
globalThis.Node = function() {};
globalThis.Event = function(type, init = {}) { this.type = type; this.detail = init.detail; };
globalThis.CustomEvent = globalThis.Event;
globalThis.MouseEvent = globalThis.Event;
globalThis.KeyboardEvent = globalThis.Event;
globalThis.navigator = { userAgent: 'node' };
globalThis.location = globalThis.window.location;
require('./build/hypersynergism.js');
console.log('bundle loaded');
'''
result = subprocess.run(['node', '-e', script], cwd=str(root), capture_output=True, text=True)
print(result.returncode)
print(result.stdout)
print(result.stderr)
# Out:
# 1
# [HSModuleManager]: Enabling Hypersynergism modules
# bundle loaded
# [HSMain]: Initialising Hypersynergism modules
# [HSPrototypes]: Enabled module 'HSPrototypes'
# [HSPrototypes]: Extending native prototypes with extra functionality
# [HSUI]: Enabled module 'HSUI'
# [HSUI]: Initialising HSUI module
#
# [HSMain]: Hypersynergism: Game load timed out, attempting init anyway...
# [HSElementHooker]: Hook timed out
# [HSUtils]: Get operation intercepted by Null Proxy 'ElementHookTimeout', something is not right
# [HSElementHooker]: Hook timed out
# [HSUtils]: Get operation intercepted by Null Proxy 'ElementHookTimeout', something is not right
# [HSElementHooker]: Hook timed out
# [HSUtils]: Get operation intercepted by Null Proxy 'ElementHookTimeout', something is not right
# [HSElementHooker]: Hook timed out
# [HSUtils]: Get operation intercepted by Null Proxy 'ElementHookTimeout', something is not right
# [HSElementHooker]: Hook timed out
# ...

# %%
from pathlib import Path
import openpyxl

script_dir = Path(r"c:/Users/tangu/Documents/Antigravity/HyperSynergism/synergism-hypersynergy/src/mod/class/hs-modules/hs-heater/temp-helper-files")
workbook_path = script_dir.parents[5] / 'docs' / 'SynergismOfficial-master' / 'Re-Octptimisation (Beta 1.2.5E)' / 'Re-Octptimisation (Beta 1.2.5E).xlsx'
wb = openpyxl.load_workbook(workbook_path, data_only=False, read_only=True)
sheet = wb['True Ambrosia Heater']
for coord in ['H6', 'H7']:
    cell = sheet[coord]
    print(coord, 'value=', cell.value, 'data_type=', cell.data_type, 'formula=', getattr(cell, 'value', None) if cell.data_type == 'f' else None)
# Out:
# H6 value= 26077876.0 data_type= n formula= None
# H7 value= 26076801.0 data_type= n formula= None
