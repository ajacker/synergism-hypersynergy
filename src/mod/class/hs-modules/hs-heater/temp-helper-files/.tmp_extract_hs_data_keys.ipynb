# %%
import sys
from pathlib import Path

repo_root = Path(r"c:\Users\tangu\Documents\Antigravity\HyperSynergism\synergism-hypersynergy")
workbook_path = repo_root / r"docs/SynergismOfficial-master/Re-Octptimisation (Beta 1.2.5E)/Re-Octptimisation (Beta 1.2.5E).xlsx"

try:
    import openpyxl
except ImportError:
    import subprocess
    subprocess.check_call([sys.executable, "-m", "pip", "install", "openpyxl"])
    import openpyxl

wb = openpyxl.load_workbook(workbook_path, data_only=False)
ws = wb['Save File Input']

for r in range(13, 57):
    x = ws[f'X{r}'].value
    y = ws[f'Y{r}'].value
    if x or y:
        print(r, {'X': x, 'Y': y})
